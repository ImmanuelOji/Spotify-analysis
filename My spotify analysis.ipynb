# %%
# In this project I am going to analyse my spotify streaming history

# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('StreamingHistory0.json')
df.head()
# Out:
#             endTime  artistName            trackName  msPlayed
# 0  2020-07-05 06:14     KNG Kay               Swerve    144870
# 1  2020-12-27 18:19  John-Li 17              Elevate    102566
# 2  2021-01-09 16:22  Blacksanta  Tonight is paradise    152925
# 3  2021-01-09 16:32  Blacksanta       You(Interlude)      2414
# 4  2021-01-09 17:03  Blacksanta       You(Interlude)    146742

# %% [markdown]
# ## Data Preparation and cleaning

# %%
df1 = pd.read_json('StreamingHistory0.json')

# %%
df1.head()
# Out:
#             endTime  artistName            trackName  msPlayed
# 0  2020-07-05 06:14     KNG Kay               Swerve    144870
# 1  2020-12-27 18:19  John-Li 17              Elevate    102566
# 2  2021-01-09 16:22  Blacksanta  Tonight is paradise    152925
# 3  2021-01-09 16:32  Blacksanta       You(Interlude)      2414
# 4  2021-01-09 17:03  Blacksanta       You(Interlude)    146742

# %%
df1.tail()
# Out:
#                endTime      artistName            trackName  msPlayed
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041

# %%
## to convert to csv
df1.to_csv = ('Spotify_data.csv')

# %%
df1
# Out:
#                endTime      artistName            trackName  msPlayed
# 0     2020-07-05 06:14         KNG Kay               Swerve    144870
# 1     2020-12-27 18:19      John-Li 17              Elevate    102566
# 2     2021-01-09 16:22      Blacksanta  Tonight is paradise    152925
# 3     2021-01-09 16:32      Blacksanta       You(Interlude)      2414
# 4     2021-01-09 17:03      Blacksanta       You(Interlude)    146742
# ...                ...             ...                  ...       ...
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041
#
# [9124 rows x 4 columns]

# %%
spotify_stream_df = df1

# %%
spotify_stream_df
# Out:
#                endTime      artistName            trackName  msPlayed
# 0     2020-07-05 06:14         KNG Kay               Swerve    144870
# 1     2020-12-27 18:19      John-Li 17              Elevate    102566
# 2     2021-01-09 16:22      Blacksanta  Tonight is paradise    152925
# 3     2021-01-09 16:32      Blacksanta       You(Interlude)      2414
# 4     2021-01-09 17:03      Blacksanta       You(Interlude)    146742
# ...                ...             ...                  ...       ...
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041
#
# [9124 rows x 4 columns]

# %%
spotify_stream_df.shape
# Out:
# (9124, 4)

# %%
spotify_stream_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9124 entries, 0 to 9123
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   endTime     9124 non-null   object
#  1   artistName  9124 non-null   object
#  2   trackName   9124 non-null   object
#  3   msPlayed    9124 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 285.2+ KB

# %%
## counting the number of unique elements

# %%
spotify_stream_df.nunique()
# Out:
# endTime       8255
# artistName     493
# trackName     1520
# msPlayed      4055
# dtype: int64

# %%
spotify_stream_df.sample(10)# to get a random sample of the data
# Out:
#                endTime       artistName  \
# 2395  2021-05-20 23:36          J. Cole
# 3285  2021-06-25 22:29            Jaden
# 3653  2021-07-13 14:11    The Kid LAROI
# 2111  2021-05-12 00:34           ArrDee
# 2310  2021-05-18 11:09        Oakstr33t
# 785   2021-02-28 23:30           Lord B
# 7349  2021-11-11 09:57  Kota the Friend
# 6413  2021-10-18 15:57       Ayra Starr
# 4512  2021-08-16 19:20            Jaden
# 3167  2021-06-18 00:09        Dami Lynn
#
#                                     trackName  msPlayed
# 2395  m y . l i f e (with 21 Savage & Morray)      2762
# 3285                                      BYE    296048
# 3653                STAY (with Justin Bieber)      1103
# 2111                       Cheeky Bars - Pt 2    152967
# 2310                              Settle Down    146339
# 785                                   Kilonso    182569
# 7349                                Away Park    253386
# 6413                                    Toxic     44255
# ...

# %%
len(spotify_stream_df['artistName'].unique()) # length of unique artists
# Out:
# 493

# %%
## I listened to 493 different artists

# %%
len(spotify_stream_df['trackName'].unique()) # length of unique tracks
# Out:
# 1520

# %%
## I listened to 1520 different songs

# %%
spotify_stream_df['Play_Time'] = pd.to_datetime(spotify_stream_df['endTime']) ## adding a new column

# %%
spotify_stream_df
# Out:
#                endTime      artistName            trackName  msPlayed  \
# 0     2020-07-05 06:14         KNG Kay               Swerve    144870
# 1     2020-12-27 18:19      John-Li 17              Elevate    102566
# 2     2021-01-09 16:22      Blacksanta  Tonight is paradise    152925
# 3     2021-01-09 16:32      Blacksanta       You(Interlude)      2414
# 4     2021-01-09 17:03      Blacksanta       You(Interlude)    146742
# ...                ...             ...                  ...       ...
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041
#
#                Play_Time
# 0    2020-07-05 06:14:00
# 1    2020-12-27 18:19:00
# 2    2021-01-09 16:22:00
# ...

# %%
spotify_stream_df['year'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).year
spotify_stream_df['month'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).month
spotify_stream_df['day'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).day
spotify_stream_df['weekday'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).weekday
spotify_stream_df['time'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).time
spotify_stream_df['hour'] = pd.DatetimeIndex(spotify_stream_df['Play_Time']).hour
spotify_stream_df['day-name'] = spotify_stream_df['Play_Time'].apply(lambda x: x.day_name())
spotify_stream_df['count'] = 1

# %%
spotify_stream_df
# Out:
#                endTime      artistName            trackName  msPlayed  \
# 0     2020-07-05 06:14         KNG Kay               Swerve    144870
# 1     2020-12-27 18:19      John-Li 17              Elevate    102566
# 2     2021-01-09 16:22      Blacksanta  Tonight is paradise    152925
# 3     2021-01-09 16:32      Blacksanta       You(Interlude)      2414
# 4     2021-01-09 17:03      Blacksanta       You(Interlude)    146742
# ...                ...             ...                  ...       ...
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041
#
#                Play_Time  year  month  day  weekday      time  hour  day-name  \
# ...

# %%
## to get the time frame of the song played in miliseconds
spotify_stream_df['Time-Played (hh-mm-ss)'] = pd.to_timedelta(spotify_stream_df['msPlayed'], unit = 'ms')

# %%
spotify_stream_df
# Out:
#                endTime      artistName            trackName  msPlayed  \
# 0     2020-07-05 06:14         KNG Kay               Swerve    144870
# 1     2020-12-27 18:19      John-Li 17              Elevate    102566
# 2     2021-01-09 16:22      Blacksanta  Tonight is paradise    152925
# 3     2021-01-09 16:32      Blacksanta       You(Interlude)      2414
# 4     2021-01-09 17:03      Blacksanta       You(Interlude)    146742
# ...                ...             ...                  ...       ...
# 9119  2022-01-03 23:30  Ajebo Hustlers                 Zamo      1026
# 9120  2022-01-03 23:30  Ajebo Hustlers            Symbiosis      1348
# 9121  2022-01-03 23:30  Ajebo Hustlers            Symbiosis       681
# 9122  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo       950
# 9123  2022-01-03 23:30  Ajebo Hustlers  Sophisticated Iyawo      1041
#
#                Play_Time  year  month  day  weekday      time  hour  day-name  \
# ...

# %%
def hours(td):
    '''To get the hour infomation'''
    return td.seconds/3600

def minutes(td):
    '''To get the minutes information'''
    return (td.seconds/60)%60

spotify_stream_df['Listening Time(Hours)'] = spotify_stream_df['Time-Played (hh-mm-ss)'].apply (hours).round(3)
spotify_stream_df['Listening Time(Minutes)'] = spotify_stream_df['Time-Played (hh-mm-ss)'].apply (minutes). round(3)

# %%
spotify_stream_df.head()
# Out:
#             endTime  artistName            trackName  msPlayed  \
# 0  2020-07-05 06:14     KNG Kay               Swerve    144870
# 1  2020-12-27 18:19  John-Li 17              Elevate    102566
# 2  2021-01-09 16:22  Blacksanta  Tonight is paradise    152925
# 3  2021-01-09 16:32  Blacksanta       You(Interlude)      2414
# 4  2021-01-09 17:03  Blacksanta       You(Interlude)    146742
#
#             Play_Time  year  month  day  weekday      time  hour  day-name  \
# 0 2020-07-05 06:14:00  2020      7    5        6  06:14:00     6    Sunday
# 1 2020-12-27 18:19:00  2020     12   27        6  18:19:00    18    Sunday
# 2 2021-01-09 16:22:00  2021      1    9        5  16:22:00    16  Saturday
# 3 2021-01-09 16:32:00  2021      1    9        5  16:32:00    16  Saturday
# 4 2021-01-09 17:03:00  2021      1    9        5  17:03:00    17  Saturday
#
#    count Time-Played (hh-mm-ss)  Listening Time(Hours)  \
# 0      1 0 days 00:02:24.870000                  0.040
# ...

# %%
spotify_stream_df.drop(columns=['endTime', 'msPlayed', 'Time-Played (hh-mm-ss)'], inplace = True)

# %%
spotify_stream_df.describe()
# Out:
#               year        month          day      weekday         hour  \
# count  9124.000000  9124.000000  9124.000000  9124.000000  9124.000000
# mean   2021.025756     7.254274    16.118588     2.970189    12.554581
# std       0.159794     3.394421     8.696672     2.025322     6.069059
# min    2020.000000     1.000000     1.000000     0.000000     0.000000
# 25%    2021.000000     5.000000     9.000000     1.000000     9.000000
# 50%    2021.000000     8.000000    16.000000     3.000000    12.000000
# 75%    2021.000000    10.000000    24.000000     5.000000    17.000000
# max    2022.000000    12.000000    31.000000     6.000000    23.000000
#
#         count  Listening Time(Hours)  Listening Time(Minutes)
# count  9124.0            9124.000000              9124.000000
# mean      1.0               0.041932                 2.516459
# std       0.0               0.024056                 1.443268
# min       1.0               0.000000                 0.000000
# ...

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %%
sns.set_style = ('dark-grid')
plt.style.use = ('seaborn-darkgrid')

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Artist Name Exploration

# %%
## Percentage of unique artists

# %%
unique_artists = spotify_stream_df['artistName'].nunique() # to count the number of unique artists
total_artists = spotify_stream_df['artistName'].count() # total number of artists

unique_artist_percentage = unique_artists/total_artists*100

unique_artist_percentage
# Out:
# 5.403331871985971

# %%
unique_artist_list = np.array([unique_artists, total_artists-unique_artists]) # Make an array out of the results
unique_artist_list_labels = [" Unique Artists", "Non Unique Artists"] # Make a lable for them

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(unique_artist_list, labels= unique_artist_list_labels, autopct='%1.1f%%',explode=[0.05,0.05] ,startangle=180, shadow = True);
plt.title("Unique Artist Percentage");

# %%
# unique artist percentage is 5.4%
# and the non unique artist percentage is 94.6%

# %%
top_10_artists = spotify_stream_df.groupby(['artistName'])[['Listening Time(Hours)', 'Listening Time(Minutes)', 'count']].sum().sort_values(by='Listening Time(Minutes)', ascending = False)
top_10_artists.head(15)
# Out:
#                  Listening Time(Hours)  Listening Time(Minutes)  count
# artistName
# Jaden                           40.180                 2411.223    847
# Kota the Friend                 20.833                 1252.130    466
# Oakstr33t                       16.801                 1008.824    422
# Smada                           16.248                  974.143    434
# Dave                            12.637                  757.853    252
# The Cavemen.                    12.615                  756.678    304
# Amaarae                         10.633                  637.569    276
# Tion Wayne                       9.904                  593.747    184
# Justin Bieber                    9.460                  568.467    233
# Ajebo Hustlers                   9.279                  558.145    313
# WizKid                           8.903                  534.949    204
# PsychoYP                         8.039                  481.963    197
# ...

# %%
top_10_artists_time = spotify_stream_df.groupby(['artistName'])[['Listening Time(Hours)', 'Listening Time(Minutes)', 'count']].sum().sort_values(by='Listening Time(Minutes)', ascending = False)
top_10_artists_time.head(10)
# Out:
#                  Listening Time(Hours)  Listening Time(Minutes)  count
# artistName
# Jaden                           40.180                 2411.223    847
# Kota the Friend                 20.833                 1252.130    466
# Oakstr33t                       16.801                 1008.824    422
# Smada                           16.248                  974.143    434
# Dave                            12.637                  757.853    252
# The Cavemen.                    12.615                  756.678    304
# Amaarae                         10.633                  637.569    276
# Tion Wayne                       9.904                  593.747    184
# Justin Bieber                    9.460                  568.467    233
# Ajebo Hustlers                   9.279                  558.145    313

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artists_time.head(10).index,top_10_artists_time["Listening Time(Hours)"].head(10),color='green')
ax.set(title="My Top 10 Favourite Artist (based on Hours)",xlabel="Artists",ylabel="No. of Hours Songs Played");
plt.xticks(rotation=75);

# %%
top_10_artists_count = spotify_stream_df.groupby(['artistName'])[['Listening Time(Hours)', 'Listening Time(Minutes)', 'count']].sum().sort_values(by = 'count', ascending = False)
top_10_artists_count.head(10)
# Out:
#                  Listening Time(Hours)  Listening Time(Minutes)  count
# artistName
# Jaden                           40.180                 2411.223    847
# Kota the Friend                 20.833                 1252.130    466
# Smada                           16.248                  974.143    434
# Oakstr33t                       16.801                 1008.824    422
# Ajebo Hustlers                   9.279                  558.145    313
# The Cavemen.                    12.615                  756.678    304
# Amaarae                         10.633                  637.569    276
# Piff Marti                       5.891                  351.132    254
# Dave                            12.637                  757.853    252
# Justin Bieber                    9.460                  568.467    233

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artists_count.head(10).index,top_10_artists_count["count"].head(10),color='orange')
ax.set(title="My Top 10 Favourite Artist (based on counts)",xlabel="Artists",ylabel="No. of Times Songs Played");
plt.xticks(rotation=75);

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))

# Setting up our first graph
ax1.bar(top_10_artists_time.head(10).index,top_10_artists_time["Listening Time(Hours)"].head(10), color="green")
ax1.set(title="My Top 10 Favourite Artist (based on Hours)",xlabel="Artists",ylabel="No. of Hours Songs Played");
ax1.tick_params(labelrotation=75);
ax1.axhline(top_10_artists_time["Listening Time(Hours)"][:100].mean(), linestyle="--", color="black")

# Setting up our seecond graph
ax2.bar(top_10_artists_count.head(10).index,top_10_artists_count["count"].head(10), color="orange")
ax2.set(title="My Top 10 Favourite Artist (based on Counts)",xlabel="Artists",ylabel="No. of Times Songs Played");
ax2.tick_params(labelrotation=75);
ax2.axhline(top_10_artists_count["count"][:100].mean(), linestyle="--", color="black");

# %% [markdown]
# ## song track exploration

# %%
spotify_stream_df
# Out:
#           artistName            trackName           Play_Time  year  month  \
# 0            KNG Kay               Swerve 2020-07-05 06:14:00  2020      7
# 1         John-Li 17              Elevate 2020-12-27 18:19:00  2020     12
# 2         Blacksanta  Tonight is paradise 2021-01-09 16:22:00  2021      1
# 3         Blacksanta       You(Interlude) 2021-01-09 16:32:00  2021      1
# 4         Blacksanta       You(Interlude) 2021-01-09 17:03:00  2021      1
# ...              ...                  ...                 ...   ...    ...
# 9119  Ajebo Hustlers                 Zamo 2022-01-03 23:30:00  2022      1
# 9120  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9121  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9122  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
# 9123  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
#
# ...

# %%
unique_tracks = spotify_stream_df['trackName'].nunique()
total_tracks = spotify_stream_df['trackName'].count()
unique_tracks_percentage = unique_tracks/total_tracks*100

unique_tracks_percentage
# Out:
# 16.659359929855327

# %%
unique_tracks_list = np.array([unique_tracks, total_tracks-unique_tracks])
unique_tracks_list_labels = [" Unique Songs", "Non Unique Songs"]

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(unique_tracks_list, labels= unique_tracks_list_labels, autopct='%1.1f%%', explode=[0.05,0.05], startangle=180, shadow = True);
plt.title("Unique Songs Percentage");

# %%
## top 10 unique songs

# %%
top_10_songs_time_df = spotify_stream_df.groupby(['trackName'])[['Listening Time(Hours)', 'Listening Time(Minutes)', 'count']].sum().sort_values(by = 'Listening Time(Minutes)', ascending = False)
top_10_songs_count_df = spotify_stream_df.groupby(['trackName'])[['Listening Time(Hours)', 'Listening Time(Minutes)', 'count']].sum().sort_values(by = 'count', ascending = False)

# %%
top_10_songs_time_df.head(10)
# Out:
#                      Listening Time(Hours)  Listening Time(Minutes)  count
# trackName
# Loyal (feat. NSG)                    4.495                  268.965     60
# Cabin Fever                          4.037                  242.767     76
# Tonight is paradise                  4.001                  240.813     93
# BYE                                  3.679                  221.261     55
# After Hours                          3.598                  215.801     67
# Settle Down                          3.592                  213.727     98
# Lazarus (feat. Boj)                  3.570                  213.381     70
# Pluto                                3.526                  211.483     85
# Solace                               3.374                  203.718    101
# Agbalagba                            3.315                  198.796     57

# %%
top_10_songs_count_df.head(10)
# Out:
#                      Listening Time(Hours)  Listening Time(Minutes)  count
# trackName
# Solace                               3.374                  203.718    101
# Settle Down                          3.592                  213.727     98
# Tonight is paradise                  4.001                  240.813     93
# Pluto                                3.526                  211.483     85
# MYSTERY RIDE                         2.180                  130.413     81
# Cabin Fever                          4.037                  242.767     76
# Gangster Love                        3.094                  186.448     74
# FAMILY                               3.191                  190.500     73
# Baby Riddim                          3.110                  186.002     71
# JUMPING SHIP                         3.245                  194.183     70

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))

# Setting up our first graph
ax1.bar(top_10_songs_time_df.head(10).index,top_10_songs_time_df["Listening Time(Hours)"].head(10), color="olive")
ax1.set(title="My Top 10 Favourite Songs",xlabel="Artists",ylabel="No. of Hours Songs Played");
ax1.tick_params(labelrotation=90);
ax1.axhline(top_10_songs_time_df["Listening Time(Hours)"][:100].mean(), linestyle="--", color="r")

# Setting up our second graph
ax2.bar(top_10_songs_count_df.head(10).index,top_10_songs_count_df["count"].head(10), color="gray")
ax2.set(title="My Top 10 Favourite Songs",xlabel="Artists",ylabel="No. of Times Songs Played");
ax2.tick_params(labelrotation=90);
ax2.axhline(top_10_songs_count_df["count"][:100].mean(), linestyle="--", color="r");

# %% [markdown]
# ## Daywise Usage exploration

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.pie(spotify_stream_df["day-name"].value_counts(), labels=spotify_stream_df["day-name"].value_counts().index, autopct='%1.1f%%', startangle=180, shadow = True);
ax.set(title="Day wise % of Spotify Streaming");

# %% [markdown]
# ## Average Usage Over a day

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.set(title="Average Distribution of Streaming Over Day Hours",xlabel="Hours (in 24 hour format)", ylabel="Songs Played")
sns.histplot(spotify_stream_df["hour"], bins=24,kde=True, color="darkgreen");

# %% [markdown]
# ## Average usage in a year

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.countplot(y=spotify_stream_df["month"], ax=ax)
ax.set(title="Average Spotify Usage over the Year", xlabel="Songs Played in Counts", ylabel="Months (1-12)");

# %% [markdown]
# ## Asking and answering questions

# %%
spotify_stream_df
# Out:
#           artistName            trackName           Play_Time  year  month  \
# 0            KNG Kay               Swerve 2020-07-05 06:14:00  2020      7
# 1         John-Li 17              Elevate 2020-12-27 18:19:00  2020     12
# 2         Blacksanta  Tonight is paradise 2021-01-09 16:22:00  2021      1
# 3         Blacksanta       You(Interlude) 2021-01-09 16:32:00  2021      1
# 4         Blacksanta       You(Interlude) 2021-01-09 17:03:00  2021      1
# ...              ...                  ...                 ...   ...    ...
# 9119  Ajebo Hustlers                 Zamo 2022-01-03 23:30:00  2022      1
# 9120  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9121  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9122  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
# 9123  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
#
# ...

# %%
time_spent_hours = spotify_stream_df['Listening Time(Hours)'].sum()

time_spent_hours
# Out:
# 382.59100000000007

# %%
## I spent 382 hours streaming on spotify from july 2020 to january 2022

# %%
spotify_stream_df.head(5)
# Out:
#    artistName            trackName           Play_Time  year  month  day  \
# 0     KNG Kay               Swerve 2020-07-05 06:14:00  2020      7    5
# 1  John-Li 17              Elevate 2020-12-27 18:19:00  2020     12   27
# 2  Blacksanta  Tonight is paradise 2021-01-09 16:22:00  2021      1    9
# 3  Blacksanta       You(Interlude) 2021-01-09 16:32:00  2021      1    9
# 4  Blacksanta       You(Interlude) 2021-01-09 17:03:00  2021      1    9
#
#    weekday      time  hour  day-name  count  Listening Time(Hours)  \
# 0        6  06:14:00     6    Sunday      1                  0.040
# 1        6  18:19:00    18    Sunday      1                  0.028
# 2        5  16:22:00    16  Saturday      1                  0.042
# 3        5  16:32:00    16  Saturday      1                  0.001
# 4        5  17:03:00    17  Saturday      1                  0.041
#
#    Listening Time(Minutes)
# 0                    2.400
# 1                    1.700
# 2                    2.533
# ...

# %%
spotify_stream_df.tail(5)
# Out:
#           artistName            trackName           Play_Time  year  month  \
# 9119  Ajebo Hustlers                 Zamo 2022-01-03 23:30:00  2022      1
# 9120  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9121  Ajebo Hustlers            Symbiosis 2022-01-03 23:30:00  2022      1
# 9122  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
# 9123  Ajebo Hustlers  Sophisticated Iyawo 2022-01-03 23:30:00  2022      1
#
#       day  weekday      time  hour day-name  count  Listening Time(Hours)  \
# 9119    3        0  23:30:00    23   Monday      1                    0.0
# 9120    3        0  23:30:00    23   Monday      1                    0.0
# 9121    3        0  23:30:00    23   Monday      1                    0.0
# 9122    3        0  23:30:00    23   Monday      1                    0.0
# 9123    3        0  23:30:00    23   Monday      1                    0.0
#
#       Listening Time(Minutes)
# 9119                    0.017
# ...

# %%
## percentage in actuacl usage

# %%
date_df = spotify_stream_df['Play_Time']

# %%
date_difference = (date_df.iloc[9123] - date_df.iloc[0])/ np.timedelta64(1,'D') ## to convert and calculate in days

date_difference_hours = date_difference*24 ## changing the days to hours
date_difference_hours
# Out:
# 13145.266666666666

# %%
time_spent_percentage = time_spent_hours/date_difference_hours*100

time_spent_percentage
# Out:
# 2.9104848893644863

# %%
hours_spent_list = np.array([time_spent_hours, date_difference_hours-time_spent_hours])
hours_spent_list_labels = [" Actual Hours Spent", "Possible Hours"]

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(hours_spent_list, labels= hours_spent_list_labels, autopct='%1.1f%%',  explode=[0.2,0.2], startangle=180, shadow = True);
plt.title("Hours Spent Percentage");

# %%
## Average number of songs i played daily

# %%
spotify_stream_df.head(10)
# Out:
#    artistName            trackName           Play_Time  year  month  day  \
# 0     KNG Kay               Swerve 2020-07-05 06:14:00  2020      7    5
# 1  John-Li 17              Elevate 2020-12-27 18:19:00  2020     12   27
# 2  Blacksanta  Tonight is paradise 2021-01-09 16:22:00  2021      1    9
# 3  Blacksanta       You(Interlude) 2021-01-09 16:32:00  2021      1    9
# 4  Blacksanta       You(Interlude) 2021-01-09 17:03:00  2021      1    9
# 5  Blacksanta          44th Avenue 2021-01-09 17:13:00  2021      1    9
# 6  Blacksanta          44th Avenue 2021-01-09 17:17:00  2021      1    9
# 7  Blacksanta        Gangster Love 2021-01-09 17:20:00  2021      1    9
# 8  Blacksanta           See cruise 2021-01-09 17:21:00  2021      1    9
# 9  Blacksanta  Tonight is paradise 2021-01-09 17:24:00  2021      1    9
#
#    weekday      time  hour  day-name  count  Listening Time(Hours)  \
# 0        6  06:14:00     6    Sunday      1                  0.040
# ...

# %%
total_songs = spotify_stream_df['trackName'].count()

total_songs
# Out:
# 9124

# %%
date_difference
# Out:
# 547.7194444444444

# %%
average_songs_played_daily = total_songs/date_difference
average_songs_played_daily
# Out:
# 16.65816339468199

# %%
## Which day did i play the maximum number of songs

# %%
spotify_stream_df['date'] = spotify_stream_df['Play_Time'].dt.date # creating new column with date

# %%
spotify_stream_df.head(5)
# Out:
#    artistName            trackName           Play_Time  year  month  day  \
# 0     KNG Kay               Swerve 2020-07-05 06:14:00  2020      7    5
# 1  John-Li 17              Elevate 2020-12-27 18:19:00  2020     12   27
# 2  Blacksanta  Tonight is paradise 2021-01-09 16:22:00  2021      1    9
# 3  Blacksanta       You(Interlude) 2021-01-09 16:32:00  2021      1    9
# 4  Blacksanta       You(Interlude) 2021-01-09 17:03:00  2021      1    9
#
#    weekday      time  hour  day-name  count  Listening Time(Hours)  \
# 0        6  06:14:00     6    Sunday      1                  0.040
# 1        6  18:19:00    18    Sunday      1                  0.028
# 2        5  16:22:00    16  Saturday      1                  0.042
# 3        5  16:32:00    16  Saturday      1                  0.001
# 4        5  17:03:00    17  Saturday      1                  0.041
#
#    Listening Time(Minutes)        date
# 0                    2.400  2020-07-05
# 1                    1.700  2020-12-27
# ...

# %%
most_songs = spotify_stream_df.groupby('date')[['count']].sum().sort_values(by = 'count', ascending = False)

most_songs.head(1)
# Out:
#             count
# date
# 2021-01-23    286

# %%
fig,ax = plt.subplots(figsize=(15,8))
ax.scatter(most_songs.index,most_songs["count"]);
ax.set(title="Maximum number of songs played in a day",xlabel="Date",ylabel="Count");
ax.axhline(most_songs["count"].mean(), linestyle="-", color="r");

# %%
## Favourite 100 artists

# %%
fav_artist = spotify_stream_df.groupby(['artistName'])['count'].count()
fav_artist.sort_values(ascending = False).head(100)
# Out:
# artistName
# Jaden              847
# Kota the Friend    466
# Smada              434
# Oakstr33t          422
# Ajebo Hustlers     313
#                   ...
# Dreckel             11
# Olamide             11
# Chimy               11
# Majid Jordan        11
# King Krule          10
# Name: count, Length: 100, dtype: int64

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
fig, ax = plt.subplots(figsize=(20,15))
wordcloud = WordCloud(width=1000,height=600, max_words=100,relative_scaling=1,normalize_plurals=False).generate_from_frequencies(fav_artist)
ax.imshow(wordcloud, interpolation='bilinear')
plt.axis(False);

# %%
## Favourite Artist Playlist

# %%
fav_artist_playlist = spotify_stream_df.groupby(['artistName', 'trackName'])[['count']].count().sort_values(by = 'count', ascending = False).head(100)

fav_artist_playlist
# Out:
#                                     count
# artistName     trackName
# Ajebo Hustlers Solace                 101
# Oakstr33t      Settle Down             98
# Blacksanta     Tonight is paradise     93
# Oakstr33t      Pluto                   85
# Smada          MYSTERY RIDE            81
# ...                                   ...
# Julia Michaels All Your Exes           22
# Smada          SMADUNSI                22
# Lojay          Monalisa                22
# Reekado Banks  Ozumba Mbadiwe          22
# The Cavemen.   Love and Trials         22
#
# [100 rows x 1 columns]

# %%
## Favourite 100 songs

# %%
fav_100_songs = spotify_stream_df.groupby(['trackName'])['count'].count()

# %%
fig, ax = plt.subplots(figsize=(20,15))
wordcloud = WordCloud(width=1000,height=600, max_words=100,relative_scaling=1,normalize_plurals=False).generate_from_frequencies(fav_100_songs)
ax.imshow(wordcloud, interpolation='bilinear')
plt.axis(False);

# %%
active_usage = spotify_stream_df.groupby(['hour', 'day-name'])['artistName'].size().reset_index()
active_usage_pivot = active_usage.pivot('hour', 'day-name', 'artistName')
active_usage_pivot.head()
# Out:
# day-name  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# hour
# 0           77.0    70.0      16.0    67.0      67.0     11.0       52.0
# 1           34.0    30.0      45.0    43.0      35.0     39.0       34.0
# 2           26.0    20.0      30.0    16.0      20.0      3.0        4.0
# 3            NaN     7.0      17.0    15.0       1.0      3.0        5.0
# 4            NaN     1.0      18.0    10.0       NaN      NaN        NaN

# %%
days = ["Monday", 'Tuesday', "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

fig, ax = plt.subplots(figsize=(15,12))
ax = sns.heatmap(active_usage_pivot[days].fillna(0), robust=True, cmap="Blues", ax = ax);
ax.set(title="Heat Map of Spotify Usage", xlabel="Days of the Week",ylabel="Time(in 24 hrs format)");

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.countplot(x=spotify_stream_df["day-name"],ax=ax)
plt.xticks(rotation=75);
ax.set(title="Average Spotify Usage over Week",xlabel="Days of the Week",ylabel="Counts of Songs Played");

# %%
## Distribution between weekdays and weekends

# %%
extra_df = spotify_stream_df.copy()
extra_df['is_weekend'] = extra_df["day-name"].isin(['Sunday','Saturday'])
weekday_vs_weekend = extra_df.groupby(['is_weekend'])[['count']].sum()
weekday_vs_weekend
# Out:
#             count
# is_weekend
# False        6501
# True         2623

# %%
weekday_vs_weekend["Percentage"] = weekday_vs_weekend["count"]/weekday_vs_weekend["count"].sum()*100
weekday_vs_weekend
# Out:
#             count  Percentage
# is_weekend
# False        6501   71.251644
# True         2623   28.748356

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(18,6))
ax1 = sns.barplot(x=["False","True"],y="count",data=weekday_vs_weekend,ax=ax1)
ax1.set(title="Weekday vs Weekend",xlabel="Is it Weekend",ylabel="Counts of Songs Played");

ax2 = sns.barplot(x=["False","True"],y="Percentage",data=weekday_vs_weekend,color="Olive",ax=ax2)
ax2.set(title="Weekday vs Weekend (Percentage)",xlabel="Is it Weekend",ylabel="Percentage of Songs Played");
